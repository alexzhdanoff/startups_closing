# %%
import pandas as pd

def encode_text_values(df, feature):

    # Подсчитываем частоту каждого уникального значения
    value_counts = df[feature].value_counts()

    # Определяем границу отсечения
    top = value_counts.nlargest(2).index

    # Создаем словарь для кодирования
    encoding_dict = {value: i+1 for i, value in enumerate(top)}

    # Функция для кодирования значения
    def encode(value):
        return encoding_dict.get(value, 0)

    # Применяем функцию кодирования к каждому значению
    df[feature] = df[feature].apply(encode)

    return df

# %%
train_data = pd.read_csv('datasets\kaggle_startups_train_28062024.csv')
display(train_data.head(10))
# Out:
#                         name  \
# 0                  Lunchgate
# 1                    EarLens
# 2     Reviva Pharmaceuticals
# 3       Sancilio and Company
# 4        WireTough Cylinders
# 5  Connected Sports Ventures
# 6                  Attensity
# 7              Mesh Networks
# 8                 AngioScore
# 9                 Vidatronic
#
#                                        category_list  funding_total_usd  \
# 0                    Online Reservations|Restaurants           828626.0
# 1              Manufacturing|Medical|Medical Devices         42935019.0
# 2                                      Biotechnology         35456381.0
# 3                                        Health Care         22250000.0
# 4                                      Manufacturing                NaN
# 5                                             Mobile          4300000.0
# 6  Analytics|Business Analytics|Social CRM|Social...         90000000.0
# ...

# %%
train_data = encode_text_values(train_data, 'category_list').head(10)

train_data
# Out:
#                         name  category_list  funding_total_usd     status  \
# 0                  Lunchgate              1           828626.0  operating
# 1                    EarLens              1         42935019.0  operating
# 2     Reviva Pharmaceuticals              2         35456381.0  operating
# 3       Sancilio and Company              1         22250000.0  operating
# 4        WireTough Cylinders              1                NaN  operating
# 5  Connected Sports Ventures              1          4300000.0  operating
# 6                  Attensity              1         90000000.0  operating
# 7              Mesh Networks              0          4300000.0  operating
# 8                 AngioScore              2         42000000.0  operating
# 9                 Vidatronic              1          1250500.0  operating
#
#   country_code state_code       region             city  funding_rounds  \
# 0          CHE         25       Zurich           Zürich               2
# ...
